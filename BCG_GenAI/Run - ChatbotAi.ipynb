# %%
import pandas as pd

# Reading the Final data report and summary report from Task 1
data1 = pd.read_csv('final_data_report.csv')
data = pd.read_csv('Summary_final_report.csv')

data1
# Out:
#    Unnamed: 0  Year  Total Revenue  Net Income  Total Assets  \
# 0           0  2023         211915       72361        411976
# 1           1  2022         198270       72738        364840
# 2           2  2021         168088       61271        333779
# 3           3  2023          96773       14974        106618
# 4           4  2022          81462       12556         82338
# 5           5  2021          53823        5519         62131
# 6           6  2023         383285       96995        352583
# 7           7  2022         394328       99803        352755
# 8           8  2021         365817       94680        351002
#
#    Total Liabilities  Cash Flow from Operating Activities    Company  \
# 0             205753                                87582  Microsoft
# 1             198298                                89035  Microsoft
# 2             191791                                76740  Microsoft
# 3              43009                                13256      Tesla
# ...

# %%
print("Year by Year Average Growth from 2021 to 2023")
data
# Out:
# Year by Year Average Growth from 2021 to 2023
#    Column1    Company  Revenue Growth (%)  Net Income Growth (%)  \
# 0        0      Apple           -1.450000              -0.746667
# 1        1  Microsoft           -7.220000              -5.080000
# 2        2      Tesla          -16.583333             -24.063333
#
#    Total Assets Growth (%)  Liabilities Growth (%)  Cash Flow Growth (%)
# 0                    -0.15               -0.226667             -1.443333
# 1                    -6.65               -2.300000             -4.050000
# 2                   -15.77              -10.480000             -3.616667

# %%
# %run Finance_AI_ChatBot.py
# Out:
# ******************************************************************************
#
# Hello! Welcome to the AI Driven Financial Chatbot!!!
#
# Hey, I can help you with your financial queries
# Please select the company name from the option below: -
#
# 1.Microsoft
# 2.Tesla
# 3.Apple
#
# The data for the fiscal year - 2023, 2022, and 2021 is currently available.
#
# The Year By Year - Average Cash Flow from Operations Growth Rate(%) from 2021 to 2023 for Apple is -1.44(%)
# ******************************************************************************
# Enter 'Hi' Properly!!!!! by starting the chatbot session again
